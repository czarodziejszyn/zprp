# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/warsaw_house_data.csv", index_col=0)

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11894 entries, 0 to 11893
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lat             11894 non-null  float64
#  1   lon             11894 non-null  float64
#  2   stop            11894 non-null  int64
#  3   bike station    11894 non-null  int64
#  4   pharmacy        11894 non-null  int64
#  5   aed             11894 non-null  int64
#  6   attraction      11894 non-null  int64
#  7   theatre         11894 non-null  int64
#  8   tree            11894 non-null  int64
#  9   bush            11894 non-null  int64
#  10  forest          11894 non-null  int64
#  11  police station  11894 non-null  int64
#  12  hotel           11894 non-null  int64
#  13  dorm            11894 non-null  int64
#  14  cost            11894 non-null  float64
# dtypes: float64(3), int64(12)
# memory usage: 1.5 MB
# ...

# %%
plt.hist(df['cost'], bins=50)
plt.title('Rozkład ceny za metr')
plt.show()

# %%
sns.boxplot(x=df['cost'])
plt.show()
